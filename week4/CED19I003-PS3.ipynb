# %% [markdown]
# ## ANALYTICS & SYSTEMS OF BIG DATA PRACTICE (COM 526P)
# Problem Set - 3
#
# 17-01-2023
#
#
# ### CED19I003
# ### Maganti Manjunadh L N Prasad

# %% [markdown]
# #### HEADER FILES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### QUESTIONS....

# %% [markdown]
# #### Question-1
#
# On New Year’s Eve, Tina walked into a random shop and surprised to see a huge crowd there. She is
# interested to find what kind of products they sell the most, for which she needs the age distribution of customers.
# Help her to find out the same using histogram. The age details of the customers are given below
# 7, 9, 27, 28, 55, 45, 34, 65, 54, 67, 34, 23, 24, 66, 53, 45, 44, 88, 22, 33, 55, 35, 33, 37, 47, 41,31, 30, 29, 12.
# Identify the type of histogram (eg. Bimodal, Multimodal, Skewed..etc). Use different bin sizes.

# %%
age = [7, 9, 27, 28, 55, 45, 34, 65, 54, 67, 34, 23, 24, 66, 53, 45, 44, 88, 22, 33, 55, 35, 33, 37, 47, 41, 31, 30, 29, 12]

plt.figure(figsize = (8, 6))

plt.subplot(2, 2, 1)
plt.hist(age, bins = [2*i for i in range(30)], edgecolor = 'yellow')

plt.subplot(2, 2, 2)
plt.hist(age, bins = [5*i for i in range(20)], edgecolor = 'green')

plt.subplot(2, 2, 3)
plt.hist(age, bins = [10*i for i in range(10)], edgecolor = 'red')

plt.subplot(2, 2, 4)
plt.hist(age, bins = [50*i for i in range(5)], edgecolor = 'black')
# Out:
# (array([22.,  8.,  0.,  0.]),
#  array([  0,  50, 100, 150, 200]),
#  <a list of 4 Patch objects>)

# %% [markdown]
# #### Question-2
#
# A Coach tracked the number of points that each of his 30 players on the team had in one game. The points
# scored by each player is given below. Visualize the data using ordered stem-leaf plot and also detect the outliers
# and shape of the distribution.
#
# 22, 21, 24, 19, 27, 28, 24, 25, 29, 28, 26, 31, 28, 27, 22, 39, 20, 10, 26, 24, 27, 28, 26, 28, 18, 32, 29, 25, 31, 27.

# %%
points = np.array([22, 21, 24, 19, 27, 28, 24 ,25, 29, 28, 26, 31, 28, 27, 22, 39, 20, 10, 26, 24, 27, 28, 26, 28, 18, 32, 29, 25, 31, 27])

x = points / 10
x = x.astype(int)
y = points % 10

plt.stem(x, y)
# Out:
# <ipython-input-3-7789956e4a02>:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(x, y)
# <StemContainer object of 3 artists>

# %% [markdown]
# ### Question-3
#
# For a sample space of 15 people, a statistician wanted to know the consumption of water and other beverages.
# He collected their average consumption of water and beverages for 30 days (in litres). Help him to visualize the
# data using density plot, rug plot and identify the mean, median, mode and skewness of the data from the plot.

# %%
water = np.array([3.2, 3.5, 3.6, 2.5, 2.8, 5.9, 2.9, 3.9, 4.9, 6.9, 7.9, 8.0, 3.3, 6.6, 4.4])
beverages = np.array([2.2, 2.5, 2.6, 1.5, 3.8, 1.9, 0.9, 3.9, 4.9, 6.9, 0.1, 8.0, 0.3, 2.6, 1.4])

plt.figure(figsize = (20, 5))

plt.subplot(1, 2, 1)
fig = sns.kdeplot(water, fill=True, color='orange')
fig = sns.rugplot(water, color = 'orange')
fig = sns.kdeplot(beverages, fill=True, color='blue')
fig = sns.rugplot(beverages, color = 'blue')

plt.subplot(1, 2, 2)
fig = sns.kdeplot(water, fill=True, color='orange')
fig = sns.kdeplot(beverages, fill=True, color='blue')
plt.axvline(x = np.mean(water), color = 'orange')
plt.axvline(x = np.mean(beverages), color = 'blue')

plt.plot()
# Out:
# []

# %% [markdown]
# ### Question-4
#
# A car company wants to predict how much fuel different cars will use based on their masses. They took a
# sample of cars, drove each car 100km, and measured how much fuel was used in each case (in litres). Visualize
# the data using scatterplot and also find co-relation between the 2 variables (eg. Positive//Negative, Linear/
# Non-linear co-relation) The data is summarized in the table below.

# %%
Mass = np.array([0.45, 0.91, 1.36, 1.81, 2.27])
Fuel = np.array([3.6, 6.7, 9.8, 11.2, 14.7])

plt.scatter(Mass, Fuel)
plt.plot(np.unique(Mass), np.poly1d(np.polyfit(Mass, Fuel, 1)) (np.unique(Mass)), color='yellow')

plt.xlabel(" Mass (metric ton) ")
plt.ylabel(" Fuel (L) ")
# Out:
# Text(0, 0.5, ' Fuel (L) ')

# %% [markdown]
# ### Question-5
#
# The data below represents the number of chairs in each class of a government high school. Create a box plot
# and swarm plot (add jitter) and find the number of data points that are outliers.
#
# 35, 54, 60, 65, 66, 67, 69, 70, 72, 73, 75, 76, 54, 25, 15, 60, 65, 66, 67, 69, 70, 72, 130, 73, 75, 76

# %%
data = [35, 54, 60, 65, 66, 67, 69, 70, 72, 73, 75, 76, 54, 25, 15, 60, 65, 66, 67, 69, 70, 72, 130, 73, 75, 76]

fig = sns.boxplot(data, color="orange")
fig = sns.swarmplot(data)
fig = sns.set({"figure.figsize" : (10, 2)})
plt.plot()
# Out:
# []

# %% [markdown]
# ### Question-6
#
# Generate random numbers from the following distribution and visualize the data using violin plot.
#
# (i) Standard-Normal distribution.
#
# (ii) Log-Normal distribution.

# %%
plt.figure(figsize = (15, 5))

snorm = np.random.normal(size=10)
print("Standard-Normal : ", snorm)
plt.subplot(2, 1, 1)
fig = sns.violinplot(snorm, orient='h', color='orange')

lnorm = np.random.lognormal(size=10)
print("Log-Normal : ", lnorm)
plt.subplot(2, 1, 2)
fig = sns.violinplot(lnorm, orient='h', color='green')
# Out:
# Standard-Normal :  [ 1.32296137  1.1589367  -1.09098778 -0.35665986 -1.60784862  1.30047286
#  -0.4045381   0.91564168  1.39641078 -1.64479419]
# Log-Normal :  [0.26142709 0.21931199 0.39115414 0.74689621 1.28124669 2.07151599
#  4.74674112 0.61813189 0.42707715 0.89100867]

# %% [markdown]
# ### Question-7
#
# An Advertisement agency develops new ads for various clients (like Jewellery shops, Textile shops). The
# Agency wants to assess their performance, for which they want to know the number of ads they developed in
# each quarter for different shop category. Help them to visualize data using radar/spider charts.

# %%
indexnames = ["Textile", "Jewellery", "Cleaning Essentials", "Cosmetics"]
q1 = np.array([10, 5, 15, 14])
q2 = np.array([6, 5, 20, 10])
q3 = np.array([8, 2, 16, 21])
q4 = np.array([13, 4, 15, 11])

data = pd.DataFrame({"Quarter 1" : q1, "Quarter 2" : q2, "Quarter 3" : q3, "Quarter 4" : q4}, index = indexnames)
data[''] = data['Quarter 1']
print(data)


angle = np.linspace(0, 2*np.pi, len(data.columns))

plt.figure(figsize=(8, 8))
plt.subplot(polar=True)

plt.plot(angle, data.iloc[0], label="Textile", linewidth=1, color='blue')
plt.fill(angle, data.iloc[0], 'blue', alpha=0.25)

plt.plot(angle, data.iloc[1], label="Jewellery", linewidth=1, color='green')
plt.fill(angle, data.iloc[1], 'green', alpha=0.25)

plt.plot(angle, data.iloc[2], label="Cleaning Essentials", linewidth=1, color='orange')
plt.fill(angle, data.iloc[2], 'orange', alpha=0.25)

plt.plot(angle, data.iloc[3], label="Cosmetics", linewidth=1, color='red')
plt.fill(angle, data.iloc[3], 'red', alpha=0.25)

labels = plt.thetagrids(np.degrees(angle), data.columns)
plt.legend()
# Out:
#                      Quarter 1  Quarter 2  Quarter 3  Quarter 4
# Textile                     10          6          8         13  10
# Jewellery                    5          5          2          4   5
# Cleaning Essentials         15         20         16         15  15
# Cosmetics                   14         10         21         11  14

# %% [markdown]
# ### Question-8
#
# An organization wants to calculate the % of time they spent on each process for their product development.
# Visualize the data using funnel chart with the data given below.

# %%
data = dict(values=[250, 180, 110 ,70, 50],
            labels=["Software Development", "Debugging & Testing", "Requirement Analysis", "Others", 'Requirement Elicitation'])
data = dict(sorted(data.items()))
fig = px.funnel(data, y='labels', x='values')
fig.show()

# %% [markdown]
# ### Question-9
#
# Let's say you are the new owner of a small ice-cream shop in a little village near the beach. You noticed that
# there was more business in the warmer months than the cooler months. Before you alter your purchasing pattern
# to match this trend, you want to be sure that the relationship is real. Help him to find the correlation between the
# data given.

# %%
Temperature = np.array([98, 87, 90, 85, 95, 75])
Customers = np.array([15, 12, 10, 10, 16, 7])

plt.scatter(Temperature, Customers)
plt.plot(np.unique(Temperature), np.poly1d(np.polyfit(Temperature, Customers, 1)) (np.unique(Temperature)), color='red')

plt.xlabel(" Temperature ")
plt.ylabel(" No. of Customers ")
# Out:
# Text(0, 0.5, ' No. of Customers ')
